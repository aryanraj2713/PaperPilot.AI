# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("papers.csv")

# %%
data.head(25)
# Out:
#     Unnamed: 0  no                                    id  \
# 0            0   1  4ab39729-af77-46f7-a662-16984fb9c1db
# 1            1   2  4ab3a4cf-1d96-4ce5-ab6f-b3e19fc260de
# 2            2   3  4ab3a98c-3620-47ec-b578-884ecf4a6206
# 3            3   4  4ab3b585-82b4-4207-91dd-b6bce7e27c4e
# 4            4   5  4ab3e768-78c9-4497-8b8e-9e934cb5f2e4
# 5            5   6  4ab3f7cd-140b-4e29-99d4-f4e8006c4f65
# 6            6   7  4ab404e2-6f4b-4fb4-b093-50775e765b13
# 7            7   8  4ab4244d-fb3e-49a3-b125-367df3d8e6ba
# 8            8   9  4ab439a4-9379-44f5-b98b-87125ae7366e
# 9            9  10  4ab459ce-5f18-4cc0-9627-1dc557eb8b68
# 10          10  11  4ab46288-3a29-471f-95c9-9926df1f93ce
# 11          11  12  4ab4c0a1-3c5a-44c6-bdd4-3a0618d303ca
# 12          12  13  4ab4c17b-a9ac-4f37-8e71-5977d5db5a07
# 13          13  14  4ab4e2a8-18c5-47a0-a295-a63dc68a49ab
# 14          14  15  4ab503e2-d7b4-441e-8e0e-edf1b9bfb602
# 15          15  16  4ab50bd7-8e59-4974-a6d0-59a577dcc10d
# 16          16  17  4ab50fd5-e0e8-44aa-acf1-a7a131293e7c
# 17          17  18  4ab54610-4947-46c7-bd56-fc672dfba5cc
# 18          18  19  4ab5585e-6a6a-4c92-b37c-e4dbb67fe72e
# 19          19  20  4ab572c2-c224-4d2e-832b-8bd440ed4da1
# 20          20  21  4ab57ebc-8bdf-4f3b-91c8-c20756fce04a
# 21          21  22  4ab59e6c-fa3b-4529-bc39-00da61e0afc4
# 22          22  23  4ab5d145-0ea8-49b5-b517-93677e7cbe88
# 23          24  25  4ab5e3f4-9b58-4fbb-9bde-ee2f2185cc61
# 24          25  26  4ab5e4bd-08e2-4007-825c-d34ce7cb231f
#
#                                                 title  \
# 0   Attractor neural networks with activity-depend...
# 1   A characterization of balanced episturmian seq...
# 2               Exploring the space of a human action
# 3   Generalized upper bounds on the minimum distan...
# 4   Applying BCMP multi-class queueing networks fo...
# 5                        A Push–Pull Class-C CMOS VCO
# 6    On computability of pattern recognition problems
# 7   Manipulating biological and mechanical micro-o...
# 8   A novel Injection Locked Rotary Traveling Wave...
# 9   An abundance of invariant polynomials satisfyi...
# 10          Entity resolution with iterative blocking
# 11          Evaluating the accuracy of Java profilers
# 12  Robust group-of-picture architecture for video...
# 13            Useful computations need useful numbers
# 14               Fast Content Aware Image Retargeting
# 15  SCADDAR: an efficient randomized technique to ...
# 16          Importance sampling in Markovian settings
# 17  Identification of cold-induced genes in cereal...
# 18                    Real-time distributed computing
# 19  On the impact of using volume as an independen...
# 20  Semantic Processing of Natural Language Querie...
# 21  A Comparison of Linear Keyword and Restricted ...
# 22  Reactive Virtual Position-Based Routing in Wir...
# 23  Novel Weighting-Delay-Based Stability Criteria...
# 24               Cross-Language Information Retrieval
#
#                                              abstract  \
# 0   We studied an autoassociative neural network w...
# 1   It is well-known that Sturmian sequences are t...
# 2   One of the fundamental challenges of recognizi...
# 3   This paper generalizes previous optimal upper ...
# 4   Queueing networks with multiple classes of cus...
# 5   A CMOS oscillator employing differential trans...
# 6   In statistical setting of the pattern recognit...
# 7   We first discuss some general aspects of micro...
# 8   A novel Injection Locked Rotary Traveling Wave...
# 9   In 1999, Iwan Duursma defined the zeta functio...
# 10  Entity Resolution (ER) is the problem of ident...
# 11  Performance analysts profile their programs to...
# 12  In motion-compensated video-coding schemes, su...
# 13  Most of us have taken the exact rational and a...
# 14  This paper addresses the problem of retargetin...
# 15  Scalable storage architectures allow for the a...
# 16  Rare event simulation for stochastic models of...
# 17  Freezing tolerance in plants is obtained durin...
# 18  This position paper concerns itself with real-...
# 19  a b s t r a c t The constant pressure–temperat...
# 20  The OntoNL Framework provides an architecture ...
# 21  This study compares a linear keyword language ...
# 22  Virtual position-based routing protocols have ...
# 23  In this paper, a weighting-delay-based method ...
# 24  Search for information is no longer exclusivel...
#
#                                 citation  \
# 0   4017c9d2-9845-4ad2-ad5b-ba65523727c5
# 1   1c655ee2-067d-4bc4-b8cc-bc779e9a7f10
# 2   056116c1-9e7a-4f9b-a918-44eb199e67d6
# 3   01a765b8-0cb3-495c-996f-29c36756b435
# 4   1c26e228-57d2-4b2c-b0c9-8d5851c17fac
# 5   0a09db01-264a-4bdf-942c-d33cceb35d3c
# 6   505f493b-e09d-444d-9ee2-5e5db6a5b8ac
# 7   5ecd70e1-7ccc-4b2f-ac09-b91953cca5cd
# 8   54f270aa-ce44-4ece-a2ca-c63a9f266cb3
# 9   02d38c7d-3baf-40e3-86d7-a8884ff503f4
# 10  0b5e0bfa-12ff-4175-9d65-d8cc62552ae6
# 11  0b279971-aa22-4622-aaf5-5cd6d4f70756
# 12  15430dbb-9ce8-4e7a-a112-678cdf1f1c28
# 13  12a6a20f-d96b-4761-a704-2182aa7e61ef
# 14  517f023f-4d1f-4f6d-96a3-7638f86b34d8
# 15  1d950f41-7ecc-4243-a2bc-e91242887637
# 16  1fbce743-ee10-495e-b67f-700928b3cfc0
# 17  9b8ad98f-1db8-4201-8246-cbc0812606d8
# 18  236bbbbd-56a9-41fa-a880-d33ab6c40c78
# 19  0983ec0b-f922-4c60-aac5-64f720fab210
# 20  06a739f6-4696-4f33-9788-7ecfd2aabc27
# 21  02ceec2a-77e5-4f0b-a0a1-a6869b7d580a
# 22  0d4d0363-07b5-43b6-976d-955e96044709
# 23  11560f85-2543-466f-b338-5ef10a073db7
# 24  05da32dc-92b9-49a6-86f0-54b6dfc51502
#
#                                            references
# 0   4017c9d2-9845-4ad2-ad5b-ba65523727c5,b1187381-...
# 1   1c655ee2-067d-4bc4-b8cc-bc779e9a7f10,2e4e57ca-...
# 2   056116c1-9e7a-4f9b-a918-44eb199e67d6,05ac52a1-...
# 3   01a765b8-0cb3-495c-996f-29c36756b435,5dbc8ccb-...
# 4   1c26e228-57d2-4b2c-b0c9-8d5851c17fac,75399207-...
# 5   0a09db01-264a-4bdf-942c-d33cceb35d3c,36c942df-...
# 6                505f493b-e09d-444d-9ee2-5e5db6a5b8ac
# 7   5ecd70e1-7ccc-4b2f-ac09-b91953cca5cd,7fa711e9-...
# 8   54f270aa-ce44-4ece-a2ca-c63a9f266cb3,638c4886-...
# 9   02d38c7d-3baf-40e3-86d7-a8884ff503f4,078e6ac3-...
# 10  0b5e0bfa-12ff-4175-9d65-d8cc62552ae6,2cba753f-...
# 11  0b279971-aa22-4622-aaf5-5cd6d4f70756,16f8c89c-...
# 12  15430dbb-9ce8-4e7a-a112-678cdf1f1c28,750b4963-...
# 13  12a6a20f-d96b-4761-a704-2182aa7e61ef,69319909-...
# 14  517f023f-4d1f-4f6d-96a3-7638f86b34d8,6a5e9cd0-...
# 15  1d950f41-7ecc-4243-a2bc-e91242887637,57868e44-...
# 16  1fbce743-ee10-495e-b67f-700928b3cfc0,5481cf9f-...
# 17  9b8ad98f-1db8-4201-8246-cbc0812606d8,e5b94864-...
# 18  236bbbbd-56a9-41fa-a880-d33ab6c40c78,2e07a585-...
# 19  0983ec0b-f922-4c60-aac5-64f720fab210,1aad0bde-...
# 20  06a739f6-4696-4f33-9788-7ecfd2aabc27,11d6d688-...
# 21  02ceec2a-77e5-4f0b-a0a1-a6869b7d580a,11aceee0-...
# 22  0d4d0363-07b5-43b6-976d-955e96044709,29424b9c-...
# 23  11560f85-2543-466f-b338-5ef10a073db7,14feaffa-...
# 24  05da32dc-92b9-49a6-86f0-54b6dfc51502,0d2d8a21-...

# %%
#null check
data.isnull().sum()
# Out:
# Unnamed: 0    0
# no            0
# id            0
# title         0
# abstract      0
# citation      0
# references    0
# dtype: int64

# %%
data.describe()
# Out:
#         Unnamed: 0           no
# count  4513.000000  4513.000000
# mean   2498.230889  2499.230889
# std    1443.658820  1443.658820
# min       0.000000     1.000000
# 25%    1251.000000  1252.000000
# 50%    2492.000000  2493.000000
# 75%    3746.000000  3747.000000
# max    5014.000000  5015.000000

# %%
data.nunique()
# Out:
# Unnamed: 0    4513
# no            4513
# id            4513
# title         4513
# abstract      4512
# citation      4209
# references    4507
# dtype: int64

# %%
#not much EDA needed


# # Data Cleaning
data = data.dropna()
#drop unneccesary columns like : Unnamed:0,id,citation,references

data = data.drop(['Unnamed: 0','id'],axis=1)

# %%
data.head(25)
# Out:
#     no                                              title  \
# 0    1  Attractor neural networks with activity-depend...
# 1    2  A characterization of balanced episturmian seq...
# 2    3              Exploring the space of a human action
# 3    4  Generalized upper bounds on the minimum distan...
# 4    5  Applying BCMP multi-class queueing networks fo...
# 5    6                       A Push–Pull Class-C CMOS VCO
# 6    7   On computability of pattern recognition problems
# 7    8  Manipulating biological and mechanical micro-o...
# 8    9  A novel Injection Locked Rotary Traveling Wave...
# 9   10  An abundance of invariant polynomials satisfyi...
# 10  11          Entity resolution with iterative blocking
# 11  12          Evaluating the accuracy of Java profilers
# 12  13  Robust group-of-picture architecture for video...
# 13  14            Useful computations need useful numbers
# 14  15               Fast Content Aware Image Retargeting
# 15  16  SCADDAR: an efficient randomized technique to ...
# 16  17          Importance sampling in Markovian settings
# 17  18  Identification of cold-induced genes in cereal...
# 18  19                    Real-time distributed computing
# 19  20  On the impact of using volume as an independen...
# 20  21  Semantic Processing of Natural Language Querie...
# 21  22  A Comparison of Linear Keyword and Restricted ...
# 22  23  Reactive Virtual Position-Based Routing in Wir...
# 23  25  Novel Weighting-Delay-Based Stability Criteria...
# 24  26               Cross-Language Information Retrieval
#
#                                              abstract  \
# 0   We studied an autoassociative neural network w...
# 1   It is well-known that Sturmian sequences are t...
# 2   One of the fundamental challenges of recognizi...
# 3   This paper generalizes previous optimal upper ...
# 4   Queueing networks with multiple classes of cus...
# 5   A CMOS oscillator employing differential trans...
# 6   In statistical setting of the pattern recognit...
# 7   We first discuss some general aspects of micro...
# 8   A novel Injection Locked Rotary Traveling Wave...
# 9   In 1999, Iwan Duursma defined the zeta functio...
# 10  Entity Resolution (ER) is the problem of ident...
# 11  Performance analysts profile their programs to...
# 12  In motion-compensated video-coding schemes, su...
# 13  Most of us have taken the exact rational and a...
# 14  This paper addresses the problem of retargetin...
# 15  Scalable storage architectures allow for the a...
# 16  Rare event simulation for stochastic models of...
# 17  Freezing tolerance in plants is obtained durin...
# 18  This position paper concerns itself with real-...
# 19  a b s t r a c t The constant pressure–temperat...
# 20  The OntoNL Framework provides an architecture ...
# 21  This study compares a linear keyword language ...
# 22  Virtual position-based routing protocols have ...
# 23  In this paper, a weighting-delay-based method ...
# 24  Search for information is no longer exclusivel...
#
#                                 citation  \
# 0   4017c9d2-9845-4ad2-ad5b-ba65523727c5
# 1   1c655ee2-067d-4bc4-b8cc-bc779e9a7f10
# 2   056116c1-9e7a-4f9b-a918-44eb199e67d6
# 3   01a765b8-0cb3-495c-996f-29c36756b435
# 4   1c26e228-57d2-4b2c-b0c9-8d5851c17fac
# 5   0a09db01-264a-4bdf-942c-d33cceb35d3c
# 6   505f493b-e09d-444d-9ee2-5e5db6a5b8ac
# 7   5ecd70e1-7ccc-4b2f-ac09-b91953cca5cd
# 8   54f270aa-ce44-4ece-a2ca-c63a9f266cb3
# 9   02d38c7d-3baf-40e3-86d7-a8884ff503f4
# 10  0b5e0bfa-12ff-4175-9d65-d8cc62552ae6
